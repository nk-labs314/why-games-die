# %% [markdown]
# # 03 Event Annotation Analysis
#
# Inspect manual events and Steam announcements that fall near detected decline windows.

# %%
import pandas as pd
events = pd.read_csv('../data/interim/normalized_events/events.csv')
windows = pd.read_csv('../data/processed/event_windows.csv')
events.head(), windows.head()
# Out:
# (     game  app_id        date          event_type         event_source  \
#  0  Dota 2     570  2024-04-19  steam_announcement  steam_announcements
#  1  Dota 2     570  2024-04-23  steam_announcement  steam_announcements
#  2  Dota 2     570  2024-05-06  steam_announcement  steam_announcements
#  3  Dota 2     570  2024-05-06  steam_announcement  steam_announcements
#  4  Dota 2     570  2024-05-23  steam_announcement  steam_announcements
#
#                                                 title  \
#  0  Dota 2 Crownfall is a new, ongoing story event...
#  1                          Dota 2 Update - 4/22/2024
#  2   Dota Labs and Crownfall Collector's Cache Voting
#  3  Dota 2's Pudge becomes the MOBA's first charac...
#  4                   Update 7.36 and Crownfall Act II
#
#                                               summary  \
#  0  <img width="900" height="507" src="https://www...
#  1  Over the last few days since Crownfall's relea...
#  2  [img]{STEAM_CLAN_IMAGE}/3703047/94c9425912362b...
#  3  <img src="https://cdn.mos.cms.futurecdn.net/8F...
#  4  [img]{STEAM_CLAN_IMAGE}/3703047/20246e3ed17e94...
#
#                                                   url confidence
#  0  https://steamstore-a.akamaihd.net/news/externa...     medium
#  1  https://steamstore-a.akamaihd.net/news/externa...     medium
#  2  https://steamstore-a.akamaihd.net/news/externa...     medium
#  3  https://steamstore-a.akamaihd.net/news/externa...     medium
#  4  https://steamstore-a.akamaihd.net/news/externa...     medium  ,
#              event_id                        game  app_id  pre_positive_ratio  \
#  0     440-2024-08-01             Team Fortress 2     440                 NaN
#  1     440-2025-01-01             Team Fortress 2     440                 NaN
#  2  200210-2012-10-01  Realm of the Mad God Exalt  200210                 NaN
#  3  200210-2014-02-01  Realm of the Mad God Exalt  200210                 NaN
#  4  200210-2018-09-01  Realm of the Mad God Exalt  200210                 NaN
#
#     during_positive_ratio  post_positive_ratio  nearby_event_count  \
#  0                    NaN                  NaN                   0
#  1                    NaN                  NaN                   0
#  2                    NaN                  NaN                   0
#  3                    NaN                  NaN                   0
#  4                    NaN                  NaN                   0
#
#    nearby_event_types classification
#  0                NaN        unknown
#  1                NaN        unknown
#  2                NaN        unknown
#  3                NaN        unknown
#  4                NaN        unknown  )
