# %% [markdown]
# # 02 Review Sentiment Overlay
#
# Review data is optional. When snapshots exist, inspect daily review aggregates around decline windows.

# %%
import pandas as pd
reviews = pd.read_csv('../data/interim/normalized_reviews/steam_reviews_daily.csv')
reviews.head()
# Out:
# Empty DataFrame
# Columns: [game, app_id, date, review_count, positive_count, negative_count, positive_ratio, avg_sentiment_score]
# Index: []
