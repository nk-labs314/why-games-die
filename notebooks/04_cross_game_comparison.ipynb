# %% [markdown]
# # 04 Cross-Game Comparison
#
# Compare candidate games using the same decline-detection rule and monthly features.

# %%
import pandas as pd
summary = pd.read_csv('../data/processed/decline_summary.csv')
features = pd.read_csv('../data/processed/monthly_features.csv')
summary
# Out:
#                          game   app_id first_month  last_month  \
# 0            Z1 Battle Royale   433850  2016-02-01  2026-04-01
# 1    STAR WARS Battlefront II  1237950  2020-06-01  2026-04-01
# 2                   New World  1063730  2021-10-01  2026-04-01
# 3            Battlefield 2042  1517290  2021-11-01  2026-04-01
# 4  Realm of the Mad God Exalt   200210  2012-07-01  2026-04-01
# 5             Team Fortress 2      440  2012-07-01  2026-04-01
# 6       ARK: Survival Evolved   346110  2015-05-01  2026-04-01
# 7                Apex Legends  1172470  2020-11-01  2026-04-01
# 8                      Dota 2      570  2012-07-01  2026-04-01
# 9         PUBG: BATTLEGROUNDS   578080  2017-03-01  2026-04-01
#
#    months_observed  peak_avg_ccu  latest_avg_ccu  latest_vs_peak_percent  \
# 0              123      86807.87          238.45                  -99.73
# 1               71      12371.81         1401.00                  -88.68
# ...
