# %% [markdown]
# # 01 Player Decline Detection
#
# Inspect monthly SteamCharts metrics and detected decline events.

# %%
import pandas as pd
metrics = pd.read_csv('../data/processed/game_daily_metrics.csv')
declines = pd.read_csv('../data/processed/decline_events.csv')
metrics.head(), declines.head()
# Out:
# (                    game  app_id        date   avg_ccu  peak_ccu       source  \
#  0  ARK: Survival Evolved  346110  2015-05-01      5.28        28  steamcharts
#  1  ARK: Survival Evolved  346110  2015-06-01  42871.49     80162  steamcharts
#  2  ARK: Survival Evolved  346110  2015-07-01  46764.79     74888  steamcharts
#  3  ARK: Survival Evolved  346110  2015-08-01  45057.02     84838  steamcharts
#  4  ARK: Survival Evolved  346110  2015-09-01  35498.30     60299  steamcharts
#
#     review_count  positive_count  negative_count  positive_ratio  \
#  0           NaN             NaN             NaN             NaN
#  1           NaN             NaN             NaN             NaN
#  2           NaN             NaN             NaN             NaN
#  3           NaN             NaN             NaN             NaN
#  4           NaN             NaN             NaN             NaN
#
#     avg_sentiment_score
#  0                  NaN
#  1                  NaN
# ...
