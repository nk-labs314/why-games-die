# %% [markdown]
# # 00 Data Availability
#
# Audit which configured games have raw source snapshots available.

# %%
import pandas as pd
pd.read_csv('../data/processed/game_summary.csv')
# Out:
#                          game   app_id  player_data_available  \
# 0                   New World  1063730                   True
# 1            Z1 Battle Royale   433850                   True
# 2                      Dota 2      570                   True
# 3         PUBG: BATTLEGROUNDS   578080                   True
# 4                Apex Legends  1172470                   True
# 5             Team Fortress 2      440                   True
# 6  Realm of the Mad God Exalt   200210                   True
# 7            Battlefield 2042  1517290                   True
# 8    STAR WARS Battlefront II  1237950                   True
# 9       ARK: Survival Evolved   346110                   True
#
#    review_data_available  announcement_data_available  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# ...
